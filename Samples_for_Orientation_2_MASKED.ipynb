# %%
# List file in ADLS
dbutils.fs.ls("/mnt/PLEASE_ENTER_YOUR_OWN_MOUNT_POINT_NAME")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[3]: [FileInfo(path=&#39;dbfs:/mnt/adbadlstest01_store01/BL-Flickr-Images-Book.csv&#39;, name=&#39;BL-Flickr-Images-Book.csv&#39;, size=2964500),
#  FileInfo(path=&#39;dbfs:/mnt/adbadlstest01_store01/pima-indians-diabetes-data.csv&#39;, name=&#39;pima-indians-diabetes-data.csv&#39;, size=23278)]</div>

# %%
# Exploring data in ADLS with Pandas, check header of dataframe
import pandas as pd
import numpy as np
df = pd.read_csv("/dbfs/mnt/PLEASE_ENTER_YOUR_OWN_MOUNT_POINT_NAME/BL-Flickr-Images-Book.csv")
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Identifier</th>
#       <th>Edition Statement</th>
#       <th>Place of Publication</th>
#       <th>Date of Publication</th>
#       <th>Publisher</th>
#       <th>Title</th>
#       <th>Author</th>
#       <th>Contributors</th>
#       <th>Corporate Author</th>
#       <th>Corporate Contributors</th>
#       <th>Former owner</th>
#       <th>Engraver</th>
#       <th>Issuance type</th>
#       <th>Flickr URL</th>
#       <th>Shelfmarks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>206</td>
#       <td>NaN</td>
#       <td>London</td>
#       <td>1879 [1878]</td>
# ...

# %%
# Dropping unnecessary columns from dataframe
to_drop = ['Edition Statement', 'Corporate Author', 'Corporate Contributors', 'Former owner', 'Engraver', 'Contributors', 'Issuance type', 'Shelfmarks']
df.drop(to_drop, inplace=True, axis=1)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Checking dataframe header again after columns drop
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Identifier</th>
#       <th>Place of Publication</th>
#       <th>Date of Publication</th>
#       <th>Publisher</th>
#       <th>Title</th>
#       <th>Author</th>
#       <th>Flickr URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>206</td>
#       <td>London</td>
#       <td>1879 [1878]</td>
#       <td>S. Tinsley &amp; Co.</td>
#       <td>Walter Forbes. [A novel.] By A. A</td>
#       <td>A. A.</td>
#       <td>http://www.flickr.com/photos/britishlibrary/ta...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>216</td>
# ...

# %%
# Checking column Identifier is unique or not
df['Identifier'].is_unique
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[11]: True</div>

# %%
# Setting column Identifier as Index
df = df.set_index('Identifier')
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Place of Publication</th>
#       <th>Date of Publication</th>
#       <th>Publisher</th>
#       <th>Title</th>
#       <th>Author</th>
#       <th>Flickr URL</th>
#     </tr>
#     <tr>
#       <th>Identifier</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>206</th>
#       <td>London</td>
#       <td>1879 [1878]</td>
#       <td>S. Tinsley &amp; Co.</td>
#       <td>Walter Forbes. [A novel.] By A. A</td>
#       <td>A. A.</td>
# ...

# %%
# Checking specifc row of record by Identifier number
df.loc[206]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[14]: Place of Publication                                               London
# Date of Publication                                           1879 [1878]
# Publisher                                                S. Tinsley &amp; Co.
# Title                                   Walter Forbes. [A novel.] By A. A
# Author                                                              A. A.
# Flickr URL              http://www.flickr.com/photos/britishlibrary/ta...
# Name: 206, dtype: object</div>

# %%
# Showing Date of Publication column value error
df.loc[1905:, 'Date of Publication'].head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[21]: Identifier
# 1905           1888
# 1929    1839, 38-54
# 2836           1897
# 2854           1865
# 2956        1860-63
# 2957           1873
# 3017           1866
# 3131           1899
# 4598           1814
# 4884           1820
# Name: Date of Publication, dtype: object</div>

# %%
# Clean Date of Publication by regular expression
extr = df['Date of Publication'].str.extract(r'^(\d{4})', expand=False)
extr.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[22]: Identifier
# 206    1879
# 216    1868
# 218    1869
# 472    1851
# 480    1857
# Name: Date of Publication, dtype: object</div>

# %%
# Change column type from object to numeric
df['Date of Publication'] = pd.to_numeric(extr)
df['Date of Publication'].dtype
df['Date of Publication'].isnull().sum() / len(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[24]: dtype(&#39;float64&#39;)</div>

# %%
df.loc[1905:, 'Date of Publication'].head(10)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[26]: Identifier
# 1905    1888.0
# 1929    1839.0
# 2836    1897.0
# 2854    1865.0
# 2956    1860.0
# 2957    1873.0
# 3017    1866.0
# 3131    1899.0
# 4598    1814.0
# 4884    1820.0
# Name: Date of Publication, dtype: float64</div>

# %%
# Check header of dataframe again
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Place of Publication</th>
#       <th>Date of Publication</th>
#       <th>Publisher</th>
#       <th>Title</th>
#       <th>Author</th>
#       <th>Flickr URL</th>
#     </tr>
#     <tr>
#       <th>Identifier</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>206</th>
#       <td>London</td>
#       <td>1879.0</td>
#       <td>S. Tinsley &amp; Co.</td>
#       <td>Walter Forbes. [A novel.] By A. A</td>
#       <td>A. A.</td>
#       <td>http://www.flickr.com/photos/britishlibrary/ta...</td>
# ...

# %%
df.to_csv (r'/dbfs/mnt/PLEASE_ENTER_YOUR_OWN_MOUNT_POINT_NAME/BL-Flickr-Images-Book-Cleaned-v1.csv', index = False, header=True)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
